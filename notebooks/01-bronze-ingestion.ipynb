# %%
customers_path = "Files/raw/customers/customers.csv"
products_path = "Files/raw/products/products.csv"
stores_path = "Files/raw/stores/stores.csv"
sales_2024_path = "Files/raw/sales/sales_2024.csv"

df_customers = spark.read.option("header",True).csv(customers_path)
df_products = spark.read.option("header",True).csv(products_path)
df_stores = spark.read.option("header",True).csv(stores_path)
df_sales = spark.read.option("header",True).csv(sales_2024_path)
# Out:
# StatementMeta(, 34f9e1a7-07ec-4286-b122-38cbfce6ae4f, 3, Finished, Available, Finished, False)

# %%
df_customers.write.mode("overwrite").saveAsTable("bronze_customers")
df_products.write.mode("overwrite").saveAsTable("bronze_products")
df_stores.write.mode("overwrite").saveAsTable("bronze_stores")
df_sales.write.mode("overwrite").saveAsTable("bronze_sales")
# Out:
# StatementMeta(, 34f9e1a7-07ec-4286-b122-38cbfce6ae4f, 8, Finished, Available, Finished, False)
